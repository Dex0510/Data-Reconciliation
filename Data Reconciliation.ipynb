# %%
#Importing the Libraries
import pandas as pd
import numpy as np
import math
import numpy as np

# %%
#Reading the Files
order = pd.read_excel('Company X - Order Report.xlsx')
pincode = pd.read_excel('Company X - Pincode Zones.xlsx')
sku = pd.read_excel('Company X - SKU Master.xlsx')
invoice = pd.read_excel('Courier Company - Invoice.xlsx')
rates = pd.read_excel('Courier Company - Rates.xlsx')
result = pd.read_excel('Expected_Result.xlsx')

# %%
#Company X - Order Report
print(order.head())
print(order.shape)
# Out:
#    ExternOrderNo            SKU  Order Qty
# 0     2001827036  8904223818706        1.0
# 1     2001827036  8904223819093        1.0
# 2     2001827036  8904223819109        1.0
# 3     2001827036  8904223818430        1.0
# 4     2001827036  8904223819277        1.0
# (400, 3)

# %%
#Company X - Pincode Zones
print(pincode.head())
print(pincode.shape)
# Out:
#    Warehouse Pincode  Customer Pincode Zone
# 0             121003            507101    d
# 1             121003            486886    d
# 2             121003            532484    d
# 3             121003            143001    b
# 4             121003            515591    d
# (124, 3)

# %%
#Company X - SKU Master
print(sku.head())
print(sku.shape)
# Out:
#              SKU  Weight (g)
# 0  8904223815682         210
# 1  8904223815859         165
# 2  8904223815866         113
# 3  8904223815873          65
# 4  8904223816214         120
# (66, 2)

# %%
#Courier Company - Invoice
print(invoice.head())
print(invoice.shape)
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30             121003
# 1  1091117222194  2001806273            1.00             121003
# 2  1091117222931  2001806408            2.50             121003
# 3  1091117223244  2001806458            1.00             121003
# 4  1091117229345  2001807012            0.15             121003
#
#    Customer Pincode Zone Type of Shipment  Billing Amount (Rs.)
# 0            507101    d  Forward charges                 135.0
# 1            486886    d  Forward charges                  90.2
# 2            532484    d  Forward charges                 224.6
# 3            143001    b  Forward charges                  61.3
# 4            515591    d  Forward charges                  45.4
# (124, 8)

# %%
invoice
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# 1              486886    d          Forward charges                  90.2
# 2              532484    d          Forward charges                 224.6
# 3              143001    b          Forward charges                  61.3
# 4              515591    d          Forward charges                  45.4
# ..                ...  ...                      ...                   ...
# 119            325207    d          Forward charges                  90.2
# 120            303702    d  Forward and RTO charges                  86.7
# 121            313301    d          Forward charges                  45.4
# 122            173212    b          Forward charges                  33.0
# 123            302020    d          Forward charges                  45.4
#
# [124 rows x 8 columns]

# %%
#Courier Company - Rates
rates
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0         29.5              23.6           33              28.3         40.1
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %%
#Merging order and sku on SKU
order = pd.merge(order,sku,on='SKU')

# %%
order
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)
# 0       2001827036  8904223818706        1.0         127
# 1       2001821995  8904223818706        1.0         127
# 2       2001819252  8904223818706        1.0         127
# 3       2001816996  8904223818706        1.0         127
# 4       2001814580  8904223818706        1.0         127
# ..             ...            ...        ...         ...
# 396     2001806616  8904223819123        1.0         250
# 397     2001806567  8904223815804        1.0         160
# 398     2001806567  8904223818577        1.0         150
# 399     2001806408  8904223819437        2.0         552
# 400     2001806232  8904223818645        6.0         137
#
# [401 rows x 4 columns]

# %%
#Converting Weight in grams to Kilogrmas and creating a new column of the same
order['Weight (kg)'] = order['Weight (g)']/1000

# %%
#Creating a new column "Additional" to make the calculation easy for calculating Weight Slab and more
order['Additional'] = (order['Weight (kg)']/0.500000001)
order['Additional'] = order['Additional'].apply(np.int64)
order['Weight slab as per X (KG)'] = ((order['Additional']+1)*0.5)

# %%
order
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)  Weight (kg)  \
# 0       2001827036  8904223818706        1.0         127        0.127
# 1       2001821995  8904223818706        1.0         127        0.127
# 2       2001819252  8904223818706        1.0         127        0.127
# 3       2001816996  8904223818706        1.0         127        0.127
# 4       2001814580  8904223818706        1.0         127        0.127
# ..             ...            ...        ...         ...          ...
# 396     2001806616  8904223819123        1.0         250        0.250
# 397     2001806567  8904223815804        1.0         160        0.160
# 398     2001806567  8904223818577        1.0         150        0.150
# 399     2001806408  8904223819437        2.0         552        0.552
# 400     2001806232  8904223818645        6.0         137        0.137
#
#      Additional  Weight slab as per X (KG)
# 0             0                        0.5
# 1             0                        0.5
# 2             0                        0.5
# 3             0                        0.5
# 4             0                        0.5
# ..          ...                        ...
# 396           0                        0.5
# 397           0                        0.5
# 398           0                        0.5
# 399           1                        1.0
# 400           0                        0.5
#
# [401 rows x 7 columns]

# %%
#Renaming it Order ID
order = order.rename(columns = {'ExternOrderNo':'Order ID'})
order
# Out:
#        Order ID            SKU  Order Qty  Weight (g)  Weight (kg)  \
# 0    2001827036  8904223818706        1.0         127        0.127
# 1    2001821995  8904223818706        1.0         127        0.127
# 2    2001819252  8904223818706        1.0         127        0.127
# 3    2001816996  8904223818706        1.0         127        0.127
# 4    2001814580  8904223818706        1.0         127        0.127
# ..          ...            ...        ...         ...          ...
# 396  2001806616  8904223819123        1.0         250        0.250
# 397  2001806567  8904223815804        1.0         160        0.160
# 398  2001806567  8904223818577        1.0         150        0.150
# 399  2001806408  8904223819437        2.0         552        0.552
# 400  2001806232  8904223818645        6.0         137        0.137
#
#      Additional  Weight slab as per X (KG)
# 0             0                        0.5
# 1             0                        0.5
# 2             0                        0.5
# 3             0                        0.5
# 4             0                        0.5
# ..          ...                        ...
# 396           0                        0.5
# 397           0                        0.5
# 398           0                        0.5
# 399           1                        1.0
# 400           0                        0.5
#
# [401 rows x 7 columns]

# %%
invoice
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# 1              486886    d          Forward charges                  90.2
# 2              532484    d          Forward charges                 224.6
# 3              143001    b          Forward charges                  61.3
# 4              515591    d          Forward charges                  45.4
# ..                ...  ...                      ...                   ...
# 119            325207    d          Forward charges                  90.2
# 120            303702    d  Forward and RTO charges                  86.7
# 121            313301    d          Forward charges                  45.4
# 122            173212    b          Forward charges                  33.0
# 123            302020    d          Forward charges                  45.4
#
# [124 rows x 8 columns]

# %%
#Merging ci and xor on Order ID
order_master = pd.merge(invoice,order,on='Order ID')

# %%
#Calculating the Total Weight
order_master['Total Weight (in KG)'] = order_master['Order Qty']*order_master['Weight (kg)']

# %%
order_master
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232             1.3             121003
# 1    1091117222124  2001806232             1.3             121003
# 2    1091117222194  2001806273             1.0             121003
# 3    1091117222194  2001806273             1.0             121003
# 4    1091117222194  2001806273             1.0             121003
# ..             ...         ...             ...                ...
# 396  1091121844806  2001811475             0.5             121003
# 397  1091121846136  2001811305             0.5             121003
# 398  1091121846136  2001811305             0.5             121003
# 399  1091121846136  2001811305             0.5             121003
# 400  1091121846136  2001811305             0.5             121003
#
#      Customer Pincode Zone Type of Shipment  Billing Amount (Rs.)  \
# 0              507101    d  Forward charges                 135.0
# 1              507101    d  Forward charges                 135.0
# 2              486886    d  Forward charges                  90.2
# 3              486886    d  Forward charges                  90.2
# 4              486886    d  Forward charges                  90.2
# ..                ...  ...              ...                   ...
# 396            173212    b  Forward charges                  33.0
# 397            302020    d  Forward charges                  45.4
# 398            302020    d  Forward charges                  45.4
# 399            302020    d  Forward charges                  45.4
# 400            302020    d  Forward charges                  45.4
#
#                SKU  Order Qty  Weight (g)  Weight (kg)  Additional  \
# 0    8904223819147        2.0         240        0.240           0
# 1    8904223818645        6.0         137        0.137           0
# 2    8904223818706        1.0         127        0.127           0
# 3    8904223818850        1.0         240        0.240           0
# 4    8904223818942        1.0         133        0.133           0
# ..             ...        ...         ...          ...         ...
# 396  8904223819499        1.0         210        0.210           0
# 397  8904223816214        1.0         120        0.120           0
# 398  8904223819512        1.0         210        0.210           0
# 399  8904223819499        1.0         210        0.210           0
# 400  8904223819505        1.0         210        0.210           0
#
#      Weight slab as per X (KG)  Total Weight (in KG)
# 0                          0.5                 0.480
# 1                          0.5                 0.822
# 2                          0.5                 0.127
# 3                          0.5                 0.240
# 4                          0.5                 0.133
# ..                         ...                   ...
# 396                        0.5                 0.210
# 397                        0.5                 0.120
# 398                        0.5                 0.210
# 399                        0.5                 0.210
# 400                        0.5                 0.210
#
# [401 rows x 15 columns]

# %%
#Dropping unnecessary columns
order_master = order_master.drop('Warehouse Pincode', 1)
order_master = order_master.drop('Customer Pincode', 1)
order_master = order_master.drop('Weight (kg)', 1)
order_master = order_master.drop('SKU', 1)
order_master = order_master.drop('Weight (g)', 1)
order_master = order_master.drop('Weight slab as per X (KG)', 1)
order_master = order_master.drop('Additional',1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
order_master
# Out:
#           AWB Code    Order ID  Charged Weight Zone Type of Shipment  \
# 0    1091117222124  2001806232             1.3    d  Forward charges
# 1    1091117222124  2001806232             1.3    d  Forward charges
# 2    1091117222194  2001806273             1.0    d  Forward charges
# 3    1091117222194  2001806273             1.0    d  Forward charges
# 4    1091117222194  2001806273             1.0    d  Forward charges
# ..             ...         ...             ...  ...              ...
# 396  1091121844806  2001811475             0.5    b  Forward charges
# 397  1091121846136  2001811305             0.5    d  Forward charges
# 398  1091121846136  2001811305             0.5    d  Forward charges
# 399  1091121846136  2001811305             0.5    d  Forward charges
# 400  1091121846136  2001811305             0.5    d  Forward charges
#
#      Billing Amount (Rs.)  Order Qty  Total Weight (in KG)
# 0                   135.0        2.0                 0.480
# 1                   135.0        6.0                 0.822
# 2                    90.2        1.0                 0.127
# 3                    90.2        1.0                 0.240
# 4                    90.2        1.0                 0.133
# ..                    ...        ...                   ...
# 396                  33.0        1.0                 0.210
# 397                  45.4        1.0                 0.120
# 398                  45.4        1.0                 0.210
# 399                  45.4        1.0                 0.210
# 400                  45.4        1.0                 0.210
#
# [401 rows x 8 columns]

# %%
order_master
# Out:
#           AWB Code    Order ID  Charged Weight Zone Type of Shipment  \
# 0    1091117222124  2001806232             1.3    d  Forward charges
# 1    1091117222124  2001806232             1.3    d  Forward charges
# 2    1091117222194  2001806273             1.0    d  Forward charges
# 3    1091117222194  2001806273             1.0    d  Forward charges
# 4    1091117222194  2001806273             1.0    d  Forward charges
# ..             ...         ...             ...  ...              ...
# 396  1091121844806  2001811475             0.5    b  Forward charges
# 397  1091121846136  2001811305             0.5    d  Forward charges
# 398  1091121846136  2001811305             0.5    d  Forward charges
# 399  1091121846136  2001811305             0.5    d  Forward charges
# 400  1091121846136  2001811305             0.5    d  Forward charges
#
#      Billing Amount (Rs.)  Order Qty  Total Weight (in KG)
# 0                   135.0        2.0                 0.480
# 1                   135.0        6.0                 0.822
# 2                    90.2        1.0                 0.127
# 3                    90.2        1.0                 0.240
# 4                    90.2        1.0                 0.133
# ..                    ...        ...                   ...
# 396                  33.0        1.0                 0.210
# 397                  45.4        1.0                 0.120
# 398                  45.4        1.0                 0.210
# 399                  45.4        1.0                 0.210
# 400                  45.4        1.0                 0.210
#
# [401 rows x 8 columns]

# %%
#creating new df to ease the calculation of total weight
final =order_master.groupby(['Order ID','AWB Code','Zone','Type of Shipment'])['Total Weight (in KG)','Billing Amount (Rs.)',].agg('sum')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
final
# Out:
#                                                        Total Weight (in KG)  \
# Order ID   AWB Code      Zone Type of Shipment
# 2001806210 1091117221940 b    Forward charges                         0.220
# 2001806226 1091117222065 d    Forward charges                         0.480
# 2001806229 1091117222080 d    Forward charges                         0.500
# 2001806232 1091117222124 d    Forward charges                         1.302
# 2001806233 1091117222135 b    Forward charges                         0.245
# ...                                                                     ...
# 2001821995 1091121183730 d    Forward charges                         0.477
# 2001822466 1091121305541 d    Forward charges                         1.376
# 2001823564 1091121666133 d    Forward and RTO charges                 0.672
# 2001825261 1091121981575 d    Forward and RTO charges                 1.557
# 2001827036 1091122418320 b    Forward charges                         2.176
#
#                                                        Billing Amount (Rs.)
# Order ID   AWB Code      Zone Type of Shipment
# 2001806210 1091117221940 b    Forward charges                         349.0
# 2001806226 1091117222065 d    Forward charges                          90.2
# 2001806229 1091117222080 d    Forward charges                         270.6
# 2001806232 1091117222124 d    Forward charges                         270.0
# 2001806233 1091117222135 b    Forward charges                         122.6
# ...                                                                     ...
# 2001821995 1091121183730 d    Forward charges                          90.8
# 2001822466 1091121305541 d    Forward charges                         270.0
# 2001823564 1091121666133 d    Forward and RTO charges                 518.4
# 2001825261 1091121981575 d    Forward and RTO charges                1725.0
# 2001827036 1091122418320 b    Forward charges                        1061.1
#
# [124 rows x 2 columns]

# %%
#Renaming
final = final.rename(columns = {'Total Weight (in KG)':'Total weight as per X (KG)'})

# %%
#deleting the index we preserved during calculation
final = final.reset_index()

# %%
final
# Out:
#        Order ID       AWB Code Zone         Type of Shipment  \
# 0    2001806210  1091117221940    b          Forward charges
# 1    2001806226  1091117222065    d          Forward charges
# 2    2001806229  1091117222080    d          Forward charges
# 3    2001806232  1091117222124    d          Forward charges
# 4    2001806233  1091117222135    b          Forward charges
# ..          ...            ...  ...                      ...
# 119  2001821995  1091121183730    d          Forward charges
# 120  2001822466  1091121305541    d          Forward charges
# 121  2001823564  1091121666133    d  Forward and RTO charges
# 122  2001825261  1091121981575    d  Forward and RTO charges
# 123  2001827036  1091122418320    b          Forward charges
#
#      Total weight as per X (KG)  Billing Amount (Rs.)
# 0                         0.220                 349.0
# 1                         0.480                  90.2
# 2                         0.500                 270.6
# 3                         1.302                 270.0
# 4                         0.245                 122.6
# ..                          ...                   ...
# 119                       0.477                  90.8
# 120                       1.376                 270.0
# 121                       0.672                 518.4
# 122                       1.557                1725.0
# 123                       2.176                1061.1
#
# [124 rows x 6 columns]

# %%
#Sorting and reseting the indexes
final.sort_values(by=['Order ID'])
final=final.reset_index(drop=True)
final
# Out:
#        Order ID       AWB Code Zone         Type of Shipment  \
# 0    2001806210  1091117221940    b          Forward charges
# 1    2001806226  1091117222065    d          Forward charges
# 2    2001806229  1091117222080    d          Forward charges
# 3    2001806232  1091117222124    d          Forward charges
# 4    2001806233  1091117222135    b          Forward charges
# ..          ...            ...  ...                      ...
# 119  2001821995  1091121183730    d          Forward charges
# 120  2001822466  1091121305541    d          Forward charges
# 121  2001823564  1091121666133    d  Forward and RTO charges
# 122  2001825261  1091121981575    d  Forward and RTO charges
# 123  2001827036  1091122418320    b          Forward charges
#
#      Total weight as per X (KG)  Billing Amount (Rs.)
# 0                         0.220                 349.0
# 1                         0.480                  90.2
# 2                         0.500                 270.6
# 3                         1.302                 270.0
# 4                         0.245                 122.6
# ..                          ...                   ...
# 119                       0.477                  90.8
# 120                       1.376                 270.0
# 121                       0.672                 518.4
# 122                       1.557                1725.0
# 123                       2.176                1061.1
#
# [124 rows x 6 columns]

# %%
invoice
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# 1              486886    d          Forward charges                  90.2
# 2              532484    d          Forward charges                 224.6
# 3              143001    b          Forward charges                  61.3
# 4              515591    d          Forward charges                  45.4
# ..                ...  ...                      ...                   ...
# 119            325207    d          Forward charges                  90.2
# 120            303702    d  Forward and RTO charges                  86.7
# 121            313301    d          Forward charges                  45.4
# 122            173212    b          Forward charges                  33.0
# 123            302020    d          Forward charges                  45.4
#
# [124 rows x 8 columns]

# %%
#Merging the Result and ci on Order ID
result = pd.merge(final,invoice,on='Order ID')

# %%
result
# Out:
#        Order ID     AWB Code_x Zone_x       Type of Shipment_x  \
# 0    2001806210  1091117221940      b          Forward charges
# 1    2001806226  1091117222065      d          Forward charges
# 2    2001806229  1091117222080      d          Forward charges
# 3    2001806232  1091117222124      d          Forward charges
# 4    2001806233  1091117222135      b          Forward charges
# ..          ...            ...    ...                      ...
# 119  2001821995  1091121183730      d          Forward charges
# 120  2001822466  1091121305541      d          Forward charges
# 121  2001823564  1091121666133      d  Forward and RTO charges
# 122  2001825261  1091121981575      d  Forward and RTO charges
# 123  2001827036  1091122418320      b          Forward charges
#
#      Total weight as per X (KG)  Billing Amount (Rs.)_x     AWB Code_y  \
# 0                         0.220                   349.0  1091117221940
# 1                         0.480                    90.2  1091117222065
# 2                         0.500                   270.6  1091117222080
# 3                         1.302                   270.0  1091117222124
# 4                         0.245                   122.6  1091117222135
# ..                          ...                     ...            ...
# 119                       0.477                    90.8  1091121183730
# 120                       1.376                   270.0  1091121305541
# 121                       0.672                   518.4  1091121666133
# 122                       1.557                  1725.0  1091121981575
# 123                       2.176                  1061.1  1091122418320
#
#      Charged Weight  Warehouse Pincode  Customer Pincode Zone_y  \
# 0              2.92             121003            140604      b
# 1              0.68             121003            723146      d
# 2              0.71             121003            421204      d
# 3              1.30             121003            507101      d
# 4              0.78             121003            263139      b
# ..              ...                ...               ...    ...
# 119            0.50             121003            342008      d
# 120            1.10             121003            342301      d
# 121            0.70             121003            492001      d
# 122            1.60             121003            517128      d
# 123            1.60             121003            173213      b
#
#           Type of Shipment_y  Billing Amount (Rs.)_y
# 0            Forward charges                   174.5
# 1            Forward charges                    90.2
# 2            Forward charges                    90.2
# 3            Forward charges                   135.0
# 4            Forward charges                    61.3
# ..                       ...                     ...
# 119          Forward charges                    45.4
# 120          Forward charges                   135.0
# 121  Forward and RTO charges                   172.8
# 122  Forward and RTO charges                   345.0
# 123          Forward charges                   117.9
#
# [124 rows x 13 columns]

# %%
#Dropping the unnecessary columns
result = result.drop('Warehouse Pincode', 1)
result = result.drop('Type of Shipment_y', 1)
result = result.drop('AWB Code_y', 1)
result = result.drop('Billing Amount (Rs.)_x', 1)
result = result.drop('Zone_y', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
result
# Out:
#        Order ID     AWB Code_x Zone_x       Type of Shipment_x  \
# 0    2001806210  1091117221940      b          Forward charges
# 1    2001806226  1091117222065      d          Forward charges
# 2    2001806229  1091117222080      d          Forward charges
# 3    2001806232  1091117222124      d          Forward charges
# 4    2001806233  1091117222135      b          Forward charges
# ..          ...            ...    ...                      ...
# 119  2001821995  1091121183730      d          Forward charges
# 120  2001822466  1091121305541      d          Forward charges
# 121  2001823564  1091121666133      d  Forward and RTO charges
# 122  2001825261  1091121981575      d  Forward and RTO charges
# 123  2001827036  1091122418320      b          Forward charges
#
#      Total weight as per X (KG)  Charged Weight  Customer Pincode  \
# 0                         0.220            2.92            140604
# 1                         0.480            0.68            723146
# 2                         0.500            0.71            421204
# 3                         1.302            1.30            507101
# 4                         0.245            0.78            263139
# ..                          ...             ...               ...
# 119                       0.477            0.50            342008
# 120                       1.376            1.10            342301
# 121                       0.672            0.70            492001
# 122                       1.557            1.60            517128
# 123                       2.176            1.60            173213
#
#      Billing Amount (Rs.)_y
# 0                     174.5
# 1                      90.2
# 2                      90.2
# 3                     135.0
# 4                      61.3
# ..                      ...
# 119                    45.4
# 120                   135.0
# 121                   172.8
# 122                   345.0
# 123                   117.9
#
# [124 rows x 8 columns]

# %%
#Renaming the Columns as per the needs
result = result.rename(columns = {'AWB Code_x':'AWB Code'})
result = result.rename(columns = {'Zone_x':'Delivery Zone charged by Courier Company'})
result = result.rename(columns = {'Billing Amount (Rs.)_y':'Charges Billed by Courier Company (Rs.)'})
result = result.rename(columns = {'Type of Shipment_x':'Type of Shipment'})
result = result.rename(columns = {'Charged Weight':'Total weight as per Courier Company (KG)'})

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 119  2001821995  1091121183730                                        d
# 120  2001822466  1091121305541                                        d
# 121  2001823564  1091121666133                                        d
# 122  2001825261  1091121981575                                        d
# 123  2001827036  1091122418320                                        b
#
#             Type of Shipment  Total weight as per X (KG)  \
# 0            Forward charges                       0.220
# 1            Forward charges                       0.480
# 2            Forward charges                       0.500
# 3            Forward charges                       1.302
# 4            Forward charges                       0.245
# ..                       ...                         ...
# 119          Forward charges                       0.477
# 120          Forward charges                       1.376
# 121  Forward and RTO charges                       0.672
# 122  Forward and RTO charges                       1.557
# 123          Forward charges                       2.176
#
#      Total weight as per Courier Company (KG)  Customer Pincode  \
# 0                                        2.92            140604
# 1                                        0.68            723146
# 2                                        0.71            421204
# 3                                        1.30            507101
# 4                                        0.78            263139
# ..                                        ...               ...
# 119                                      0.50            342008
# 120                                      1.10            342301
# 121                                      0.70            492001
# 122                                      1.60            517128
# 123                                      1.60            173213
#
#      Charges Billed by Courier Company (Rs.)
# 0                                      174.5
# 1                                       90.2
# 2                                       90.2
# 3                                      135.0
# 4                                       61.3
# ..                                       ...
# 119                                     45.4
# 120                                    135.0
# 121                                    172.8
# 122                                    345.0
# 123                                    117.9
#
# [124 rows x 8 columns]

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 119  2001821995  1091121183730                                        d
# 120  2001822466  1091121305541                                        d
# 121  2001823564  1091121666133                                        d
# 122  2001825261  1091121981575                                        d
# 123  2001827036  1091122418320                                        b
#
#             Type of Shipment  Total weight as per X (KG)  \
# 0            Forward charges                       0.220
# 1            Forward charges                       0.480
# 2            Forward charges                       0.500
# 3            Forward charges                       1.302
# 4            Forward charges                       0.245
# ..                       ...                         ...
# 119          Forward charges                       0.477
# 120          Forward charges                       1.376
# 121  Forward and RTO charges                       0.672
# 122  Forward and RTO charges                       1.557
# 123          Forward charges                       2.176
#
#      Total weight as per Courier Company (KG)  Customer Pincode  \
# 0                                        2.92            140604
# 1                                        0.68            723146
# 2                                        0.71            421204
# 3                                        1.30            507101
# 4                                        0.78            263139
# ..                                        ...               ...
# 119                                      0.50            342008
# 120                                      1.10            342301
# 121                                      0.70            492001
# 122                                      1.60            517128
# 123                                      1.60            173213
#
#      Charges Billed by Courier Company (Rs.)
# 0                                      174.5
# 1                                       90.2
# 2                                       90.2
# 3                                      135.0
# 4                                       61.3
# ..                                       ...
# 119                                     45.4
# 120                                    135.0
# 121                                    172.8
# 122                                    345.0
# 123                                    117.9
#
# [124 rows x 8 columns]

# %%
#Merging the result and xpz on Customer Pincode to link Delivery Zone as per X
result = pd.merge(result,pincode,on='Customer Pincode')

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 169  2001821995  1091121183730                                        d
# 170  2001822466  1091121305541                                        d
# 171  2001823564  1091121666133                                        d
# 172  2001825261  1091121981575                                        d
# 173  2001827036  1091122418320                                        b
#
#             Type of Shipment  Total weight as per X (KG)  \
# 0            Forward charges                       0.220
# 1            Forward charges                       0.480
# 2            Forward charges                       0.500
# 3            Forward charges                       1.302
# 4            Forward charges                       0.245
# ..                       ...                         ...
# 169          Forward charges                       0.477
# 170          Forward charges                       1.376
# 171  Forward and RTO charges                       0.672
# 172  Forward and RTO charges                       1.557
# 173          Forward charges                       2.176
#
#      Total weight as per Courier Company (KG)  Customer Pincode  \
# 0                                        2.92            140604
# 1                                        0.68            723146
# 2                                        0.71            421204
# 3                                        1.30            507101
# 4                                        0.78            263139
# ..                                        ...               ...
# 169                                      0.50            342008
# 170                                      1.10            342301
# 171                                      0.70            492001
# 172                                      1.60            517128
# 173                                      1.60            173213
#
#      Charges Billed by Courier Company (Rs.)  Warehouse Pincode Zone
# 0                                      174.5             121003    b
# 1                                       90.2             121003    d
# 2                                       90.2             121003    d
# 3                                      135.0             121003    d
# 4                                       61.3             121003    b
# ..                                       ...                ...  ...
# 169                                     45.4             121003    b
# 170                                    135.0             121003    b
# 171                                    172.8             121003    d
# 172                                    345.0             121003    d
# 173                                    117.9             121003    e
#
# [174 rows x 10 columns]

# %%
#Dropping and Renaming as per requirement
result = result.drop('Warehouse Pincode', 1)
result = result.rename(columns = {'Zone':'Delivery Zone as per X'})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 169  2001821995  1091121183730                                        d
# 170  2001822466  1091121305541                                        d
# 171  2001823564  1091121666133                                        d
# 172  2001825261  1091121981575                                        d
# 173  2001827036  1091122418320                                        b
#
#             Type of Shipment  Total weight as per X (KG)  \
# 0            Forward charges                       0.220
# 1            Forward charges                       0.480
# 2            Forward charges                       0.500
# 3            Forward charges                       1.302
# 4            Forward charges                       0.245
# ..                       ...                         ...
# 169          Forward charges                       0.477
# 170          Forward charges                       1.376
# 171  Forward and RTO charges                       0.672
# 172  Forward and RTO charges                       1.557
# 173          Forward charges                       2.176
#
#      Total weight as per Courier Company (KG)  Customer Pincode  \
# 0                                        2.92            140604
# 1                                        0.68            723146
# 2                                        0.71            421204
# 3                                        1.30            507101
# 4                                        0.78            263139
# ..                                        ...               ...
# 169                                      0.50            342008
# 170                                      1.10            342301
# 171                                      0.70            492001
# 172                                      1.60            517128
# 173                                      1.60            173213
#
#      Charges Billed by Courier Company (Rs.) Delivery Zone as per X
# 0                                      174.5                      b
# 1                                       90.2                      d
# 2                                       90.2                      d
# 3                                      135.0                      d
# 4                                       61.3                      b
# ..                                       ...                    ...
# 169                                     45.4                      b
# 170                                    135.0                      b
# 171                                    172.8                      d
# 172                                    345.0                      d
# 173                                    117.9                      e
#
# [174 rows x 9 columns]

# %%
#Calculating Weight slab charged by Courier Company (KG)

result['Additionals as per Courier Company'] = (result['Total weight as per Courier Company (KG)']/0.5)
result['Additionals as per Courier Company'] = result['Additionals as per Courier Company'].apply(np.int64)
result['Weight slab charged by Courier Company (KG)'] = ((result['Additionals as per Courier Company']+1)*0.5)


#Calculating Weight slab as per X (KG)

result['Additionals as per X'] = (result['Total weight as per X (KG)']/0.5)
result['Additionals as per X'] = result['Additionals as per X'].apply(np.int64)
result['Weight slab as per X (KG)'] = ((result['Additionals as per X']+1)*0.5)

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 169  2001821995  1091121183730                                        d
# 170  2001822466  1091121305541                                        d
# 171  2001823564  1091121666133                                        d
# 172  2001825261  1091121981575                                        d
# 173  2001827036  1091122418320                                        b
#
#             Type of Shipment  Total weight as per X (KG)  \
# 0            Forward charges                       0.220
# 1            Forward charges                       0.480
# 2            Forward charges                       0.500
# 3            Forward charges                       1.302
# 4            Forward charges                       0.245
# ..                       ...                         ...
# 169          Forward charges                       0.477
# 170          Forward charges                       1.376
# 171  Forward and RTO charges                       0.672
# 172  Forward and RTO charges                       1.557
# 173          Forward charges                       2.176
#
#      Total weight as per Courier Company (KG)  Customer Pincode  \
# 0                                        2.92            140604
# 1                                        0.68            723146
# 2                                        0.71            421204
# 3                                        1.30            507101
# 4                                        0.78            263139
# ..                                        ...               ...
# 169                                      0.50            342008
# 170                                      1.10            342301
# 171                                      0.70            492001
# 172                                      1.60            517128
# 173                                      1.60            173213
#
#      Charges Billed by Courier Company (Rs.) Delivery Zone as per X  \
# 0                                      174.5                      b
# 1                                       90.2                      d
# 2                                       90.2                      d
# 3                                      135.0                      d
# 4                                       61.3                      b
# ..                                       ...                    ...
# 169                                     45.4                      b
# 170                                    135.0                      b
# 171                                    172.8                      d
# 172                                    345.0                      d
# 173                                    117.9                      e
#
#      Additionals as per Courier Company  \
# 0                                     5
# 1                                     1
# 2                                     1
# 3                                     2
# 4                                     1
# ..                                  ...
# 169                                   0
# 170                                   2
# 171                                   1
# 172                                   3
# 173                                   3
#
#      Weight slab charged by Courier Company (KG)  Additionals as per X  \
# 0                                            3.0                     0
# 1                                            1.0                     0
# 2                                            1.0                     0
# 3                                            1.5                     2
# 4                                            1.0                     0
# ..                                           ...                   ...
# 169                                          0.5                     0
# 170                                          1.5                     2
# 171                                          1.0                     1
# 172                                          2.0                     3
# 173                                          2.0                     4
#
#      Weight slab as per X (KG)
# 0                          0.5
# 1                          0.5
# 2                          0.5
# 3                          1.5
# 4                          0.5
# ..                         ...
# 169                        0.5
# 170                        1.5
# 171                        1.0
# 172                        2.0
# 173                        2.5
#
# [174 rows x 13 columns]

# %%
#Dropping Pincode now
result = result.drop('Customer Pincode', 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 169  2001821995  1091121183730                                        d
# 170  2001822466  1091121305541                                        d
# 171  2001823564  1091121666133                                        d
# 172  2001825261  1091121981575                                        d
# 173  2001827036  1091122418320                                        b
#
#             Type of Shipment  Total weight as per X (KG)  \
# 0            Forward charges                       0.220
# 1            Forward charges                       0.480
# 2            Forward charges                       0.500
# 3            Forward charges                       1.302
# 4            Forward charges                       0.245
# ..                       ...                         ...
# 169          Forward charges                       0.477
# 170          Forward charges                       1.376
# 171  Forward and RTO charges                       0.672
# 172  Forward and RTO charges                       1.557
# 173          Forward charges                       2.176
#
#      Total weight as per Courier Company (KG)  \
# 0                                        2.92
# 1                                        0.68
# 2                                        0.71
# 3                                        1.30
# 4                                        0.78
# ..                                        ...
# 169                                      0.50
# 170                                      1.10
# 171                                      0.70
# 172                                      1.60
# 173                                      1.60
#
#      Charges Billed by Courier Company (Rs.) Delivery Zone as per X  \
# 0                                      174.5                      b
# 1                                       90.2                      d
# 2                                       90.2                      d
# 3                                      135.0                      d
# 4                                       61.3                      b
# ..                                       ...                    ...
# 169                                     45.4                      b
# 170                                    135.0                      b
# 171                                    172.8                      d
# 172                                    345.0                      d
# 173                                    117.9                      e
#
#      Additionals as per Courier Company  \
# 0                                     5
# 1                                     1
# 2                                     1
# 3                                     2
# 4                                     1
# ..                                  ...
# 169                                   0
# 170                                   2
# 171                                   1
# 172                                   3
# 173                                   3
#
#      Weight slab charged by Courier Company (KG)  Additionals as per X  \
# 0                                            3.0                     0
# 1                                            1.0                     0
# 2                                            1.0                     0
# 3                                            1.5                     2
# 4                                            1.0                     0
# ..                                           ...                   ...
# 169                                          0.5                     0
# 170                                          1.5                     2
# 171                                          1.0                     1
# 172                                          2.0                     3
# 173                                          2.0                     4
#
#      Weight slab as per X (KG)
# 0                          0.5
# 1                          0.5
# 2                          0.5
# 3                          1.5
# 4                          0.5
# ..                         ...
# 169                        0.5
# 170                        1.5
# 171                        1.0
# 172                        2.0
# 173                        2.5
#
# [174 rows x 12 columns]

# %%
rates
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0         29.5              23.6           33              28.3         40.1
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %%
#Just successfully tried a very different apprach to solve this problem. NEED ATTENTION!!
result['Additional or not'] = result['Additionals as per X'].astype(str)

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 169  2001821995  1091121183730                                        d
# 170  2001822466  1091121305541                                        d
# 171  2001823564  1091121666133                                        d
# 172  2001825261  1091121981575                                        d
# 173  2001827036  1091122418320                                        b
#
#             Type of Shipment  Total weight as per X (KG)  \
# 0            Forward charges                       0.220
# 1            Forward charges                       0.480
# 2            Forward charges                       0.500
# 3            Forward charges                       1.302
# 4            Forward charges                       0.245
# ..                       ...                         ...
# 169          Forward charges                       0.477
# 170          Forward charges                       1.376
# 171  Forward and RTO charges                       0.672
# 172  Forward and RTO charges                       1.557
# 173          Forward charges                       2.176
#
#      Total weight as per Courier Company (KG)  \
# 0                                        2.92
# 1                                        0.68
# 2                                        0.71
# 3                                        1.30
# 4                                        0.78
# ..                                        ...
# 169                                      0.50
# 170                                      1.10
# 171                                      0.70
# 172                                      1.60
# 173                                      1.60
#
#      Charges Billed by Courier Company (Rs.) Delivery Zone as per X  \
# 0                                      174.5                      b
# 1                                       90.2                      d
# 2                                       90.2                      d
# 3                                      135.0                      d
# 4                                       61.3                      b
# ..                                       ...                    ...
# 169                                     45.4                      b
# 170                                    135.0                      b
# 171                                    172.8                      d
# 172                                    345.0                      d
# 173                                    117.9                      e
#
#      Additionals as per Courier Company  \
# 0                                     5
# 1                                     1
# 2                                     1
# 3                                     2
# 4                                     1
# ..                                  ...
# 169                                   0
# 170                                   2
# 171                                   1
# 172                                   3
# 173                                   3
#
#      Weight slab charged by Courier Company (KG)  Additionals as per X  \
# 0                                            3.0                     0
# 1                                            1.0                     0
# 2                                            1.0                     0
# 3                                            1.5                     2
# 4                                            1.0                     0
# ..                                           ...                   ...
# 169                                          0.5                     0
# 170                                          1.5                     2
# 171                                          1.0                     1
# 172                                          2.0                     3
# 173                                          2.0                     4
#
#      Weight slab as per X (KG) Additional or not
# 0                          0.5                 0
# 1                          0.5                 0
# 2                          0.5                 0
# 3                          1.5                 2
# 4                          0.5                 0
# ..                         ...               ...
# 169                        0.5                 0
# 170                        1.5                 2
# 171                        1.0                 1
# 172                        2.0                 3
# 173                        2.5                 4
#
# [174 rows x 13 columns]

# %%
#This is the first part of the Approach
result['Combo'] = result['Delivery Zone charged by Courier Company']+result['Type of Shipment']

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 169  2001821995  1091121183730                                        d
# 170  2001822466  1091121305541                                        d
# 171  2001823564  1091121666133                                        d
# 172  2001825261  1091121981575                                        d
# 173  2001827036  1091122418320                                        b
#
#             Type of Shipment  Total weight as per X (KG)  \
# 0            Forward charges                       0.220
# 1            Forward charges                       0.480
# 2            Forward charges                       0.500
# 3            Forward charges                       1.302
# 4            Forward charges                       0.245
# ..                       ...                         ...
# 169          Forward charges                       0.477
# 170          Forward charges                       1.376
# 171  Forward and RTO charges                       0.672
# 172  Forward and RTO charges                       1.557
# 173          Forward charges                       2.176
#
#      Total weight as per Courier Company (KG)  \
# 0                                        2.92
# 1                                        0.68
# 2                                        0.71
# 3                                        1.30
# 4                                        0.78
# ..                                        ...
# 169                                      0.50
# 170                                      1.10
# 171                                      0.70
# 172                                      1.60
# 173                                      1.60
#
#      Charges Billed by Courier Company (Rs.) Delivery Zone as per X  \
# 0                                      174.5                      b
# 1                                       90.2                      d
# 2                                       90.2                      d
# 3                                      135.0                      d
# 4                                       61.3                      b
# ..                                       ...                    ...
# 169                                     45.4                      b
# 170                                    135.0                      b
# 171                                    172.8                      d
# 172                                    345.0                      d
# 173                                    117.9                      e
#
#      Additionals as per Courier Company  \
# 0                                     5
# 1                                     1
# 2                                     1
# 3                                     2
# 4                                     1
# ..                                  ...
# 169                                   0
# 170                                   2
# 171                                   1
# 172                                   3
# 173                                   3
#
#      Weight slab charged by Courier Company (KG)  Additionals as per X  \
# 0                                            3.0                     0
# 1                                            1.0                     0
# 2                                            1.0                     0
# 3                                            1.5                     2
# 4                                            1.0                     0
# ..                                           ...                   ...
# 169                                          0.5                     0
# 170                                          1.5                     2
# 171                                          1.0                     1
# 172                                          2.0                     3
# 173                                          2.0                     4
#
#      Weight slab as per X (KG) Additional or not                     Combo
# 0                          0.5                 0          bForward charges
# 1                          0.5                 0          dForward charges
# 2                          0.5                 0          dForward charges
# 3                          1.5                 2          dForward charges
# 4                          0.5                 0          bForward charges
# ..                         ...               ...                       ...
# 169                        0.5                 0          dForward charges
# 170                        1.5                 2          dForward charges
# 171                        1.0                 1  dForward and RTO charges
# 172                        2.0                 3  dForward and RTO charges
# 173                        2.5                 4          bForward charges
#
# [174 rows x 14 columns]

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 169  2001821995  1091121183730                                        d
# 170  2001822466  1091121305541                                        d
# 171  2001823564  1091121666133                                        d
# 172  2001825261  1091121981575                                        d
# 173  2001827036  1091122418320                                        b
#
#             Type of Shipment  Total weight as per X (KG)  \
# 0            Forward charges                       0.220
# 1            Forward charges                       0.480
# 2            Forward charges                       0.500
# 3            Forward charges                       1.302
# 4            Forward charges                       0.245
# ..                       ...                         ...
# 169          Forward charges                       0.477
# 170          Forward charges                       1.376
# 171  Forward and RTO charges                       0.672
# 172  Forward and RTO charges                       1.557
# 173          Forward charges                       2.176
#
#      Total weight as per Courier Company (KG)  \
# 0                                        2.92
# 1                                        0.68
# 2                                        0.71
# 3                                        1.30
# 4                                        0.78
# ..                                        ...
# 169                                      0.50
# 170                                      1.10
# 171                                      0.70
# 172                                      1.60
# 173                                      1.60
#
#      Charges Billed by Courier Company (Rs.) Delivery Zone as per X  \
# 0                                      174.5                      b
# 1                                       90.2                      d
# 2                                       90.2                      d
# 3                                      135.0                      d
# 4                                       61.3                      b
# ..                                       ...                    ...
# 169                                     45.4                      b
# 170                                    135.0                      b
# 171                                    172.8                      d
# 172                                    345.0                      d
# 173                                    117.9                      e
#
#      Additionals as per Courier Company  \
# 0                                     5
# 1                                     1
# 2                                     1
# 3                                     2
# 4                                     1
# ..                                  ...
# 169                                   0
# 170                                   2
# 171                                   1
# 172                                   3
# 173                                   3
#
#      Weight slab charged by Courier Company (KG)  Additionals as per X  \
# 0                                            3.0                     0
# 1                                            1.0                     0
# 2                                            1.0                     0
# 3                                            1.5                     2
# 4                                            1.0                     0
# ..                                           ...                   ...
# 169                                          0.5                     0
# 170                                          1.5                     2
# 171                                          1.0                     1
# 172                                          2.0                     3
# 173                                          2.0                     4
#
#      Weight slab as per X (KG) Additional or not                     Combo
# 0                          0.5                 0          bForward charges
# 1                          0.5                 0          dForward charges
# 2                          0.5                 0          dForward charges
# 3                          1.5                 2          dForward charges
# 4                          0.5                 0          bForward charges
# ..                         ...               ...                       ...
# 169                        0.5                 0          dForward charges
# 170                        1.5                 2          dForward charges
# 171                        1.0                 1  dForward and RTO charges
# 172                        2.0                 3  dForward and RTO charges
# 173                        2.5                 4          bForward charges
#
# [174 rows x 14 columns]

# %%
#Checking whether the a,c and d were useful or not. But still made function for them for future perspective
result['Delivery Zone as per X'].unique()
# Out:
# array(['b', 'd', 'e'], dtype=object)

# %%
result['Final Price acc X'] = 0

count_row = result.shape[0]  # Gives number of rows
for i in range(count_row):
    if result['Combo'][i]=='aForward charges':
        result['Final Price acc X'][i] = 29.5 + (result['Additionals as per X'][i]*23.6)



    if result['Combo'][i]=='bForward charges':
        result['Final Price acc X'][i] = 33 + (result['Additionals as per X'][i]*28.3)



    if result['Combo'][i]=='cForward charges':
        result['Final Price acc X'][i] = 40.1 + (result['Additionals as per X'][i]*38.9)


    if result['Combo'][i]=='dForward charges':
        result['Final Price acc X'][i] = 45.4 + (result['Additionals as per X'][i]*44.8)


    if result['Combo'][i]=='eForward charges':
        result['Final Price acc X'][i] = 56.6 + (result['Additionals as per X'][i]*55.5)



    if result['Combo'][i]=='aForward and RTO charges':
        result['Final Price acc X'][i] = 29.5 + 13.6 + (result['Additionals as per X'][i]*23.6) + (result['Additionals as per X'][i]*23.6) 


    if result['Combo'][i]=='bForward and RTO charges':
        result['Final Price acc X'][i] = 33 + 20.5 +(result['Additionals as per X'][i]*33) + (result['Additionals as per X'][i]*28.3)


    if result['Combo'][i]=='cForward and RTO charges':
        result['Final Price acc X'][i] = 40.1 + 31.9 + (result['Additionals as per X'][i]*40.1) + (result['Additionals as per X'][i]*38.9)


    if result['Combo'][i]=='dForward and RTO charges':
        result['Final Price acc X'][i] = 45.4 + 41.3 + (result['Additionals as per X'][i]*45.4) + (result['Additionals as per X'][i]*44.8)


    if result['Combo'][i]=='eForward and RTO charges':
        result['Final Price acc X'][i] = 56.6 +50.7 + (result['Additionals as per X'][i]*56.6) + (result['Additionals as per X'][i]*55.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 169  2001821995  1091121183730                                        d
# 170  2001822466  1091121305541                                        d
# 171  2001823564  1091121666133                                        d
# 172  2001825261  1091121981575                                        d
# 173  2001827036  1091122418320                                        b
#
#             Type of Shipment  Total weight as per X (KG)  \
# 0            Forward charges                       0.220
# 1            Forward charges                       0.480
# 2            Forward charges                       0.500
# 3            Forward charges                       1.302
# 4            Forward charges                       0.245
# ..                       ...                         ...
# 169          Forward charges                       0.477
# 170          Forward charges                       1.376
# 171  Forward and RTO charges                       0.672
# 172  Forward and RTO charges                       1.557
# 173          Forward charges                       2.176
#
#      Total weight as per Courier Company (KG)  \
# 0                                        2.92
# 1                                        0.68
# 2                                        0.71
# 3                                        1.30
# 4                                        0.78
# ..                                        ...
# 169                                      0.50
# 170                                      1.10
# 171                                      0.70
# 172                                      1.60
# 173                                      1.60
#
#      Charges Billed by Courier Company (Rs.) Delivery Zone as per X  \
# 0                                      174.5                      b
# 1                                       90.2                      d
# 2                                       90.2                      d
# 3                                      135.0                      d
# 4                                       61.3                      b
# ..                                       ...                    ...
# 169                                     45.4                      b
# 170                                    135.0                      b
# 171                                    172.8                      d
# 172                                    345.0                      d
# 173                                    117.9                      e
#
#      Additionals as per Courier Company  \
# 0                                     5
# 1                                     1
# 2                                     1
# 3                                     2
# 4                                     1
# ..                                  ...
# 169                                   0
# 170                                   2
# 171                                   1
# 172                                   3
# 173                                   3
#
#      Weight slab charged by Courier Company (KG)  Additionals as per X  \
# 0                                            3.0                     0
# 1                                            1.0                     0
# 2                                            1.0                     0
# 3                                            1.5                     2
# 4                                            1.0                     0
# ..                                           ...                   ...
# 169                                          0.5                     0
# 170                                          1.5                     2
# 171                                          1.0                     1
# 172                                          2.0                     3
# 173                                          2.0                     4
#
#      Weight slab as per X (KG) Additional or not                     Combo  \
# 0                          0.5                 0          bForward charges
# 1                          0.5                 0          dForward charges
# 2                          0.5                 0          dForward charges
# 3                          1.5                 2          dForward charges
# 4                          0.5                 0          bForward charges
# ..                         ...               ...                       ...
# 169                        0.5                 0          dForward charges
# 170                        1.5                 2          dForward charges
# 171                        1.0                 1  dForward and RTO charges
# 172                        2.0                 3  dForward and RTO charges
# 173                        2.5                 4          bForward charges
#
#      Final Price acc X
# 0                   33
# 1                   45
# 2                   45
# 3                  135
# 4                   33
# ..                 ...
# 169                 45
# 170                135
# 171                176
# 172                357
# 173                146
#
# [174 rows x 15 columns]

# %%
output_data_1 = result.copy(deep=True)

# %%
output_data_1
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 169  2001821995  1091121183730                                        d
# 170  2001822466  1091121305541                                        d
# 171  2001823564  1091121666133                                        d
# 172  2001825261  1091121981575                                        d
# 173  2001827036  1091122418320                                        b
#
#             Type of Shipment  Total weight as per X (KG)  \
# 0            Forward charges                       0.220
# 1            Forward charges                       0.480
# 2            Forward charges                       0.500
# 3            Forward charges                       1.302
# 4            Forward charges                       0.245
# ..                       ...                         ...
# 169          Forward charges                       0.477
# 170          Forward charges                       1.376
# 171  Forward and RTO charges                       0.672
# 172  Forward and RTO charges                       1.557
# 173          Forward charges                       2.176
#
#      Total weight as per Courier Company (KG)  \
# 0                                        2.92
# 1                                        0.68
# 2                                        0.71
# 3                                        1.30
# 4                                        0.78
# ..                                        ...
# 169                                      0.50
# 170                                      1.10
# 171                                      0.70
# 172                                      1.60
# 173                                      1.60
#
#      Charges Billed by Courier Company (Rs.) Delivery Zone as per X  \
# 0                                      174.5                      b
# 1                                       90.2                      d
# 2                                       90.2                      d
# 3                                      135.0                      d
# 4                                       61.3                      b
# ..                                       ...                    ...
# 169                                     45.4                      b
# 170                                    135.0                      b
# 171                                    172.8                      d
# 172                                    345.0                      d
# 173                                    117.9                      e
#
#      Additionals as per Courier Company  \
# 0                                     5
# 1                                     1
# 2                                     1
# 3                                     2
# 4                                     1
# ..                                  ...
# 169                                   0
# 170                                   2
# 171                                   1
# 172                                   3
# 173                                   3
#
#      Weight slab charged by Courier Company (KG)  Additionals as per X  \
# 0                                            3.0                     0
# 1                                            1.0                     0
# 2                                            1.0                     0
# 3                                            1.5                     2
# 4                                            1.0                     0
# ..                                           ...                   ...
# 169                                          0.5                     0
# 170                                          1.5                     2
# 171                                          1.0                     1
# 172                                          2.0                     3
# 173                                          2.0                     4
#
#      Weight slab as per X (KG) Additional or not                     Combo  \
# 0                          0.5                 0          bForward charges
# 1                          0.5                 0          dForward charges
# 2                          0.5                 0          dForward charges
# 3                          1.5                 2          dForward charges
# 4                          0.5                 0          bForward charges
# ..                         ...               ...                       ...
# 169                        0.5                 0          dForward charges
# 170                        1.5                 2          dForward charges
# 171                        1.0                 1  dForward and RTO charges
# 172                        2.0                 3  dForward and RTO charges
# 173                        2.5                 4          bForward charges
#
#      Final Price acc X
# 0                   33
# 1                   45
# 2                   45
# 3                  135
# 4                   33
# ..                 ...
# 169                 45
# 170                135
# 171                176
# 172                357
# 173                146
#
# [174 rows x 15 columns]

# %%
#Removing all the columns which are not useful now.

result = result.drop('Type of Shipment', 1)
result = result.drop('Additionals as per Courier Company', 1)
result = result.drop('Additionals as per X', 1)
result = result.drop('Additional or not', 1)
result = result.drop('Combo', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 169  2001821995  1091121183730                                        d
# 170  2001822466  1091121305541                                        d
# 171  2001823564  1091121666133                                        d
# 172  2001825261  1091121981575                                        d
# 173  2001827036  1091122418320                                        b
#
#      Total weight as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                         0.220                                      2.92
# 1                         0.480                                      0.68
# 2                         0.500                                      0.71
# 3                         1.302                                      1.30
# 4                         0.245                                      0.78
# ..                          ...                                       ...
# 169                       0.477                                      0.50
# 170                       1.376                                      1.10
# 171                       0.672                                      0.70
# 172                       1.557                                      1.60
# 173                       2.176                                      1.60
#
#      Charges Billed by Courier Company (Rs.) Delivery Zone as per X  \
# 0                                      174.5                      b
# 1                                       90.2                      d
# 2                                       90.2                      d
# 3                                      135.0                      d
# 4                                       61.3                      b
# ..                                       ...                    ...
# 169                                     45.4                      b
# 170                                    135.0                      b
# 171                                    172.8                      d
# 172                                    345.0                      d
# 173                                    117.9                      e
#
#      Weight slab charged by Courier Company (KG)  Weight slab as per X (KG)  \
# 0                                            3.0                        0.5
# 1                                            1.0                        0.5
# 2                                            1.0                        0.5
# 3                                            1.5                        1.5
# 4                                            1.0                        0.5
# ..                                           ...                        ...
# 169                                          0.5                        0.5
# 170                                          1.5                        1.5
# 171                                          1.0                        1.0
# 172                                          2.0                        2.0
# 173                                          2.0                        2.5
#
#      Final Price acc X
# 0                   33
# 1                   45
# 2                   45
# 3                  135
# 4                   33
# ..                 ...
# 169                 45
# 170                135
# 171                176
# 172                357
# 173                146
#
# [174 rows x 10 columns]

# %%
#Renaming
result = result.rename(columns = {'Final Price acc X':'Expected Charge as per X (Rs.)'})


#Generating a new column that is the Difference Between Expected Charges and Billed Charges (Rs.)
result['Difference Between Expected Charges and Billed Charges (Rs.)'] = result['Expected Charge as per X (Rs.)'] - result['Charges Billed by Courier Company (Rs.)']

# %%
result
# Out:
#        Order ID       AWB Code Delivery Zone charged by Courier Company  \
# 0    2001806210  1091117221940                                        b
# 1    2001806226  1091117222065                                        d
# 2    2001806229  1091117222080                                        d
# 3    2001806232  1091117222124                                        d
# 4    2001806233  1091117222135                                        b
# ..          ...            ...                                      ...
# 169  2001821995  1091121183730                                        d
# 170  2001822466  1091121305541                                        d
# 171  2001823564  1091121666133                                        d
# 172  2001825261  1091121981575                                        d
# 173  2001827036  1091122418320                                        b
#
#      Total weight as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                         0.220                                      2.92
# 1                         0.480                                      0.68
# 2                         0.500                                      0.71
# 3                         1.302                                      1.30
# 4                         0.245                                      0.78
# ..                          ...                                       ...
# 169                       0.477                                      0.50
# 170                       1.376                                      1.10
# 171                       0.672                                      0.70
# 172                       1.557                                      1.60
# 173                       2.176                                      1.60
#
#      Charges Billed by Courier Company (Rs.) Delivery Zone as per X  \
# 0                                      174.5                      b
# 1                                       90.2                      d
# 2                                       90.2                      d
# 3                                      135.0                      d
# 4                                       61.3                      b
# ..                                       ...                    ...
# 169                                     45.4                      b
# 170                                    135.0                      b
# 171                                    172.8                      d
# 172                                    345.0                      d
# 173                                    117.9                      e
#
#      Weight slab charged by Courier Company (KG)  Weight slab as per X (KG)  \
# 0                                            3.0                        0.5
# 1                                            1.0                        0.5
# 2                                            1.0                        0.5
# 3                                            1.5                        1.5
# 4                                            1.0                        0.5
# ..                                           ...                        ...
# 169                                          0.5                        0.5
# 170                                          1.5                        1.5
# 171                                          1.0                        1.0
# 172                                          2.0                        2.0
# 173                                          2.0                        2.5
#
#      Expected Charge as per X (Rs.)  \
# 0                                33
# 1                                45
# 2                                45
# 3                               135
# 4                                33
# ..                              ...
# 169                              45
# 170                             135
# 171                             176
# 172                             357
# 173                             146
#
#      Difference Between Expected Charges and Billed Charges (Rs.)
# 0                                               -141.5
# 1                                                -45.2
# 2                                                -45.2
# 3                                                  0.0
# 4                                                -28.3
# ..                                                 ...
# 169                                               -0.4
# 170                                                0.0
# 171                                                3.2
# 172                                               12.0
# 173                                               28.1
#
# [174 rows x 11 columns]

# %%
#Rearranging all the columns as per the need
result = result.iloc[:, [0,1,3,8,4,7,6,2,9,5,10]]

# %%
result
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                       0.220
# 1    2001806226  1091117222065                       0.480
# 2    2001806229  1091117222080                       0.500
# 3    2001806232  1091117222124                       1.302
# 4    2001806233  1091117222135                       0.245
# ..          ...            ...                         ...
# 169  2001821995  1091121183730                       0.477
# 170  2001822466  1091121305541                       1.376
# 171  2001823564  1091121666133                       0.672
# 172  2001825261  1091121981575                       1.557
# 173  2001827036  1091122418320                       2.176
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# 2                          0.5                                      0.71
# 3                          1.5                                      1.30
# 4                          0.5                                      0.78
# ..                         ...                                       ...
# 169                        0.5                                      0.50
# 170                        1.5                                      1.10
# 171                        1.0                                      0.70
# 172                        2.0                                      1.60
# 173                        2.5                                      1.60
#
#      Weight slab charged by Courier Company (KG) Delivery Zone as per X  \
# 0                                            3.0                      b
# 1                                            1.0                      d
# 2                                            1.0                      d
# 3                                            1.5                      d
# 4                                            1.0                      b
# ..                                           ...                    ...
# 169                                          0.5                      b
# 170                                          1.5                      b
# 171                                          1.0                      d
# 172                                          2.0                      d
# 173                                          2.0                      e
#
#     Delivery Zone charged by Courier Company  Expected Charge as per X (Rs.)  \
# 0                                          b                              33
# 1                                          d                              45
# 2                                          d                              45
# 3                                          d                             135
# 4                                          b                              33
# ..                                       ...                             ...
# 169                                        d                              45
# 170                                        d                             135
# 171                                        d                             176
# 172                                        d                             357
# 173                                        b                             146
#
#      Charges Billed by Courier Company (Rs.)  \
# 0                                      174.5
# 1                                       90.2
# 2                                       90.2
# 3                                      135.0
# 4                                       61.3
# ..                                       ...
# 169                                     45.4
# 170                                    135.0
# 171                                    172.8
# 172                                    345.0
# 173                                    117.9
#
#      Difference Between Expected Charges and Billed Charges (Rs.)
# 0                                               -141.5
# 1                                                -45.2
# 2                                                -45.2
# 3                                                  0.0
# 4                                                -28.3
# ..                                                 ...
# 169                                               -0.4
# 170                                                0.0
# 171                                                3.2
# 172                                               12.0
# 173                                               28.1
#
# [174 rows x 11 columns]

# %%
#Calculating Status, Count, Amount of:
#Total Orders - Correctly Charged - y,q
#Total Orders - Over Charged - z,r
#Total Orders - Under Charged - x,p


x,y,z = 0, 0, 0
p,q,r = 0, 0, 0

# iterating each number in list
for num in result['Difference Between Expected Charges and Billed Charges (Rs.)']:
    if num > 0:
        x += 1
    elif num == 0:
        y +=1
    else:
        z += 1


for i in range(count_row):
    if result['Difference Between Expected Charges and Billed Charges (Rs.)'][i]>0:
        p=p+result['Difference Between Expected Charges and Billed Charges (Rs.)'][i]
        
    elif result['Difference Between Expected Charges and Billed Charges (Rs.)'][i]==0:
        q=q+result['Expected Charge as per X (Rs.)'][i]
        
    elif result['Difference Between Expected Charges and Billed Charges (Rs.)'][i]<0:
        r=r+result['Difference Between Expected Charges and Billed Charges (Rs.)'][i]

# %%
Correctly_Charged = {y:q}
Over_Charged = {z:r}
Under_Charged = {x:p}



print(Correctly_Charged) 
print(Over_Charged)
print(Under_Charged)
# Out:
# {6: 504}
# {145: -4303.199999999989}
# {23: 581.4}

# %%
#Creating dataframe for the final outcomes
output = pd.DataFrame({
   "Count": [y,z,x],
   "Amount": [q,r,p]
})


index = pd.Index(['Total Orders - Correctly Charged','Total Orders - Over Charged','Total Orders - Under Charged'])
output = output.set_index(index)

# %%
output
# Out:
#                                   Count  Amount
# Total Orders - Correctly Charged      6   504.0
# Total Orders - Over Charged         145 -4303.2
# Total Orders - Under Charged         23   581.4

# %%
result
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                       0.220
# 1    2001806226  1091117222065                       0.480
# 2    2001806229  1091117222080                       0.500
# 3    2001806232  1091117222124                       1.302
# 4    2001806233  1091117222135                       0.245
# ..          ...            ...                         ...
# 169  2001821995  1091121183730                       0.477
# 170  2001822466  1091121305541                       1.376
# 171  2001823564  1091121666133                       0.672
# 172  2001825261  1091121981575                       1.557
# 173  2001827036  1091122418320                       2.176
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# 2                          0.5                                      0.71
# 3                          1.5                                      1.30
# 4                          0.5                                      0.78
# ..                         ...                                       ...
# 169                        0.5                                      0.50
# 170                        1.5                                      1.10
# 171                        1.0                                      0.70
# 172                        2.0                                      1.60
# 173                        2.5                                      1.60
#
#      Weight slab charged by Courier Company (KG) Delivery Zone as per X  \
# 0                                            3.0                      b
# 1                                            1.0                      d
# 2                                            1.0                      d
# 3                                            1.5                      d
# 4                                            1.0                      b
# ..                                           ...                    ...
# 169                                          0.5                      b
# 170                                          1.5                      b
# 171                                          1.0                      d
# 172                                          2.0                      d
# 173                                          2.0                      e
#
#     Delivery Zone charged by Courier Company  Expected Charge as per X (Rs.)  \
# 0                                          b                              33
# 1                                          d                              45
# 2                                          d                              45
# 3                                          d                             135
# 4                                          b                              33
# ..                                       ...                             ...
# 169                                        d                              45
# 170                                        d                             135
# 171                                        d                             176
# 172                                        d                             357
# 173                                        b                             146
#
#      Charges Billed by Courier Company (Rs.)  \
# 0                                      174.5
# 1                                       90.2
# 2                                       90.2
# 3                                      135.0
# 4                                       61.3
# ..                                       ...
# 169                                     45.4
# 170                                    135.0
# 171                                    172.8
# 172                                    345.0
# 173                                    117.9
#
#      Difference Between Expected Charges and Billed Charges (Rs.)
# 0                                               -141.5
# 1                                                -45.2
# 2                                                -45.2
# 3                                                  0.0
# 4                                                -28.3
# ..                                                 ...
# 169                                               -0.4
# 170                                                0.0
# 171                                                3.2
# 172                                               12.0
# 173                                               28.1
#
# [174 rows x 11 columns]

# %%
# saving the excel

summary = 'summary.xlsx'
output.to_excel(summary)
print('Summary is written to Excel File successfully.')

# saving the excel

calculations = 'calculations.xlsx'
result.to_excel(calculations)
print('Calculations are written to Excel File successfully.')
# Out:
# Summary is written to Excel File successfully.
# Calculations are written to Excel File successfully.
